# %% [markdown]
# # ISSM helper
#
# A collection of functions to help run ISSM a little more intuitively.

# %%
######################
### ISSM functions ###
######################

from DepthAverage import DepthAverage
from frictionweertman import frictionweertman
from InterpFromGridToMesh import InterpFromGridToMesh
from InterpFromMeshToMesh2d import InterpFromMeshToMesh2d
from project3d import project3d
from project2d import project2d
from setflowequation import setflowequation
from solve import solve

#######################
### python packages ###
#######################

import matplotlib.pyplot as plt
import numpy as np
import os, sys
import rasterio
from rasterio.fill import fillnodata
from rasterio.warp import transform
from shapely import LineString, points, distance, Point, Polygon, contains_xy as contains
from shapely.ops import nearest_points, split, unary_union, linemerge
from types import SimpleNamespace
import warnings

# %% [markdown]
# ## ```solve_quiet```
#
# Avoid all ISSM's default output, which gets annoying if iterating over multiple timesteps.

# %%
class Null:
    
    def write(self, *_): pass
    def flush(self): pass

null = Null()

def solve_quiet(md, solver_type):
    
    dn = os.open(os.devnull, os.O_WRONLY)
    o1, o2 = os.dup(1), os.dup(2)
    s1, s2 = sys.stdout, sys.stderr
    sys.stdout = null; sys.stderr = null
    os.dup2(dn, 1); os.dup2(dn, 2); os.close(dn)
    try:
        return solve(md, solver_type)
    finally:
        os.dup2(o1, 1); os.dup2(o2, 2)
        os.close(o1); os.close(o2)
        sys.stdout = s1; sys.stderr = s2

# %% [markdown]
# ## ```initialize_model```
#
# Set up model parameters that are unlikely to change during a simulation.

# %%
def initialize_model(md, **kwargs):

    approx = kwargs.get('approximation', None)
    waterline = kwargs.get('waterline', None)
    bed = kwargs.get('bed', None)
    
    T = kwargs.get('temperature', 273.15)

    ice_levelset = kwargs.get('ice_levelset', md.mask.ice_levelset)
    ocean_levelset = kwargs.get('ocean_levelset', md.mask.ocean_levelset)
    Γ_x = kwargs.get('dirichlet_x', np.zeros(md.mesh.numberofvertices).astype(bool))
    Γ_y = kwargs.get('dirichlet_y', np.zeros(md.mesh.numberofvertices).astype(bool))
    Γ_in = kwargs.get('dirichlet_H', np.zeros(md.mesh.numberofvertices).astype(bool))
    
    friction_law = kwargs.get('friction_law', lambda x: x)
    # p = kwargs.get('p', 1)
    # q = kwargs.get('q', 1)
    m = kwargs.get('m', 3)
    
    md.miscellaneous.name = kwargs.get('name', 'name')
    requested_outputs = kwargs.get('requested_outputs', [])
    vertical_layers = kwargs.get('vertical_layers', 5)
    extrusion_exponent = kwargs.get('extrusion_exponent', 1)

    ####################
    ## approximation ###
    ####################

    if approx is None:
        if not (md.flowequation.isHO or md.flowequation.isSSA):
            raise RuntimeError('Choose either "HO" or "SSA" as a flow approximation. This can by done by (a) passing "approximation" as an argument, '
            'or (b) setting setflowequation(md, f"{approximation}", "all").')
        else: 
            md = setflowequation(md, 'HO', 'all') if md.flowequation.isHO else setflowequation(md, 'SSA', 'all')
    else:
        md = setflowequation(md, approx, 'all')
        
    ############################
    ### mesh characteristics ###
    ############################

    num_e = md.mesh.numberofelements
    num_v = md.mesh.numberofvertices
    md.miscellaneous.vertical_layers = vertical_layers if md.flowequation.isHO else np.nan
    md.miscellaneous.extrusion_exponent = extrusion_exponent if md.flowequation.isHO else np.nan
    md.miscellaneous.is3d = True if md.flowequation.isHO else False
    md.miscellaneous.is2d = ~md.miscellaneous.is3d

    if np.all(np.isnan(ice_levelset)) and np.all(np.isnan(ocean_levelset)):
        
        raise RuntimeError('Set an ice and/or ocean levelset. This can be done by (a) passing "ice_levelset" or "ocean_levelset" as arguments, '
        'or (b) setting md.mesh.ice_levelset or md.mesh.ocean_levelset independently. The size of either must be equal to md.mesh.numberofvertices. '
        'For ice_levelset, +/0/- = ice/grounding line/no ice, and for ocean_levelset, +/0/- = grounded/grounding line/floating.')
    
    elif np.all(np.isnan(ice_levelset)):
        
        print('Warning: Assuming the entire domain is ice-covered. Correct by passing ice_levelset as an argument, '
        'or by otherwise setting md.mesh.ice_levelset.')
        ice_levelset = -np.ones_like(ocean_levelset)

    elif np.all(np.isnan(ocean_levelset)):

        if md.flowequation.isSSA:
            print('Warning: Assuming all ice is floating. Correct by passing ocean_levelset as an argument, '
            'or by otherwise setting md.mesh.ocean_levelset.')
            ocean_levelset = -np.ones_like(ice_levelset)
        else:
            print('Warning: Assuming all ice is grounded. Correct by passing ocean_levelset as an argument, '
            'or by otherwise setting md.mesh.ocean_levelset.')
            ocean_levelset = np.ones_like(ice_levelset)

    md.mask.ice_levelset = ice_levelset
    md.mask.ocean_levelset = ocean_levelset 

    ################
    ### geometry ###
    ################

    if waterline is None:
        if md.flowequation.isSSA:
            print('Warning: Assuming waterline is at z = 0.')
            waterline = 0
        else:
            print('Warning: Assuming waterline is below the lowest bed elevation.')
            waterline = np.min(bed) - 1e5
    md.miscellaneous.waterline = waterline

    if bed is None and np.any(md.mask.ocean_levelset > 0):
        raise RuntimeError('Either set a bed elevation or ensure ice is fully floating (with md.mesh.ocean_levelset < 0 everywhere).')
    elif bed is None:
        bed = -1e5
        
    bed = bed*np.ones(num_v) if np.isscalar(bed) else bed
    md.geometry.bed, md.miscellaneous.bed = bed, bed #miscellaneous.bed will store a 2D version even if the mesh becomes extruded

    md.geometry.thickness = np.ones(num_v) #initialize as ones and zeros to first normalize ζ
    md.geometry.surface = np.ones(num_v) #this only matters if the mesh becomes extruded
    md.geometry.base = np.zeros(num_v) #but will be very useful in that case 

    ################
    ### rheology ###
    ################
    
    T = np.array([T]) if np.isscalar(T) else T
    T_t = 263.15 #transition temperature (K)
    Q = 115e3*np.ones_like(T)
    Q[T < T_t] = 6e4
    A_0 = 3.5e-25 #rate prefactor (s^-1 Pa^-3)
    R = 8.314 #gas constant (J mol^-1 K^-1)
    A = A_0*np.exp(-Q/R*(1/T - 1/T_t)) #final rate factor (s^-1 Pa^-3)
    B = A**(-1/md.materials.rheology_n)
    md.materials.rheology_B = B
    md.miscellaneous.rheology_A = A
    md.miscellaneous.temperature = T

    ################
    ### friction ###
    ################

    md.friction = frictionweertman()
    # md.friction.p = p*np.ones(num_e) if np.isscalar(p) else p
    # md.friction.q = q*np.ones(num_e) if np.isscalar(q) else q
    md.friction.m = m*np.ones(num_e) if np.isscalar(m) else m
    # md.miscellaneous.friction_p = p
    # md.miscellaneous.friction_q = q
    md.miscellaneous.friction_law = friction_law

    ################################
    ### set dirichlet boundaries ###
    ################################

    md.stressbalance.spcvx = np.nan*np.ones(num_v)
    md.stressbalance.spcvy = np.nan*np.ones(num_v)
    md.stressbalance.spcvz = np.nan*np.ones(num_v)
    md.masstransport.spcthickness = np.nan*np.ones(num_v)

    Γ_x = np.isfinite(np.array(Γ_x)) if np.nan in Γ_x else np.array(Γ_x).astype(bool)
    Γ_y = np.isfinite(np.array(Γ_y)) if np.nan in Γ_y else np.array(Γ_y).astype(bool)
    Γ_in = np.isfinite(np.array(Γ_in)) if np.nan in Γ_in else np.array(Γ_in).astype(bool)

    try: 
        md.stressbalance.spcvx[Γ_x] = 1
        md.stressbalance.spcvy[Γ_y] = 1
        md.masstransport.spcthickness[Γ_in] = 1
    except:
        proj = lambda x: project3d(md, 'vector', x, 'type', 'node')
        md.stressbalance.spcvx[proj(Γ_x)] = 1
        md.stressbalance.spcvy[proj(Γ_y)] = 1
        md.masstransport.spcthickness[proj(Γ_in)] = 1     
        
    ##############
    ### extras ###
    ##############

    requested_outputs = list(requested_outputs)
    requested_outputs += ['default', 'StrainRatexx', 'StrainRateyy', 'StrainRatexy']
    if md.flowequation.isHO:
        requested_outputs += ['StrainRatexz', 'StrainRateyz', 'StrainRatezz']
    md.stressbalance.requested_outputs = requested_outputs
    md.miscellaneous.requested_outputs = requested_outputs

    md.stressbalance.referential = np.nan*np.ones((num_v, 6))
    md.stressbalance.loadingforce = np.zeros((num_v, 3))
    md.basalforcings.groundedice_melting_rate = np.zeros(num_v)
    md.basalforcings.floatingice_melting_rate = np.zeros(num_v)
    md.smb.initialize(md) 

    ############################
    ### extrude if necessary ###
    ############################

    if not hasattr(md.mesh, 'x2d'):
        md.miscellaneous.mesh2d = md.mesh
        if md.flowequation.isHO:
            md = md.extrude(vertical_layers, extrusion_exponent, 1)
            md.miscellaneous.zeta = md.mesh.z #this will tell us how z is distributed proportionally
            md.miscellaneous.is3d = True
            md.miscellaneous.is2d = False

# %% [markdown]
# ## ```diagnostic_solve```
#
# Use mirrors ```icepack```'s function of the same name.

# %%
def diagnostic_solve(md, **kwargs):
    
    H = kwargs['thickness']
    bed = kwargs.get('bed', md.geometry.bed.copy())
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)
    u = kwargs.get('velocity', None)
    C = kwargs.get('friction', None)
    quiet = kwargs.get('quiet', True)

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    ####################
    ### set geometry ###
    ####################

    ice_mask = md.mask.ice_levelset <= 0
    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    has_ocean = True in (hb < 0)

    b = bed.copy()
    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        float_mask = np.zeros_like(H, dtype = bool)

    s = b + H

    md.geometry.thickness = H
    md.geometry.base = b
    md.geometry.surface = s
    md.geometry.bed = bed

    ######################
    ### basal friction ###
    ######################

    if C is None:
        if md.flowequation.isSSA:
            C = 0
        else:
            raise RuntimeError('Must specify friction coefficient.')

    friction_law = md.miscellaneous.friction_law
    C = friction_law(C)

    md.friction.C = C*np.ones(md.mesh.numberofvertices) if np.isscalar(C) else C
    if has_ocean:
        md.friction.C[float_mask] = 0.0

    ####################################
    ### velocity boundary conditions ###
    ####################################

    Γ_x = np.isfinite(md.stressbalance.spcvx)
    Γ_y = np.isfinite(md.stressbalance.spcvy)

    if True in Γ_x | Γ_y:
        if u is None:
            raise RuntimeError('Must provide initial velocity to enforce Dirichlet BCs.')
        md.stressbalance.spcvx[Γ_x] = u[0] if np.isscalar(u[0]) else u[0][Γ_x]
        md.stressbalance.spcvy[Γ_y] = u[1] if np.isscalar(u[1]) else u[1][Γ_y]

    #####################
    ### update mesh.z ###
    #####################

    if is3d:
        ζ = md.miscellaneous.zeta
        md.mesh.z = b + ζ*H - waterline

    ##################
    ### solve step ###
    ##################

    md.geometry.bed -= waterline
    md.geometry.surface -= waterline
    md.geometry.base -= waterline

    md = solve_quiet(md, 'Stressbalance') if quiet else solve(md, 'Stressbalance')
    solution = md.results.StressbalanceSolution

    u_x, u_y = solution.Vx.flatten(), solution.Vy.flatten()
    u = (u_x, u_y)
    if is3d:
        u = (u_x, u_y, solution.Vz.flatten())

    ######################
    ### postprocessing ###
    ######################

    outputs = md.stressbalance.requested_outputs
    requested = [o for o in outputs if o != 'default']
    md.miscellaneous.outputs = SimpleNamespace(**{name: getattr(solution, name) for name in requested})

    ################################
    ### update floating levelset ###
    ################################

    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b = bed.copy()
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        b = bed.copy()

    s = b + H

    md.geometry.thickness = H
    md.geometry.base = b
    md.geometry.surface = s
    md.geometry.bed = bed

    if has_ocean:
        md.mask.ocean_levelset = hb + ϱ*H
    else:
        md.mask.ocean_levelset = np.ones_like(H)

    ##############
    ### return ###
    ##############
    
    return u

# %% [markdown]
# ## ```prognostic_solve```
#
# Use mirrors ```icepack```'s function of the same name, but returns both thickness and surface elevation fields.

# %%
def prognostic_solve(md, Δt, **kwargs):
    
    H = kwargs['thickness']
    u = kwargs['velocity']
    
    bed = kwargs.get('bed', md.geometry.bed.copy())
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)
    H_in = kwargs.get('thickness_inflow', None)
    quiet = kwargs.get('quiet', True)
    stab = kwargs.get('stabilization', 0)

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    ###########################
    ### resize if necessary ###
    ###########################

    if is3d:
        if (not np.isscalar(H)) and (np.size(H) < md.mesh.numberofvertices):
            H = proj3(H)
        if (H_in is not None) and (not np.isscalar(H_in)) and (np.size(H_in) < md.mesh.numberofvertices):
            H_in = proj3(H_in)

    ####################
    ### set geometry ###
    ####################

    ice_mask = md.mask.ice_levelset <= 0
    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    has_ocean = True in (hb < 0)

    b = bed.copy()
    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        float_mask = np.zeros_like(H, dtype = bool)

    s = b + H

    md.geometry.thickness = H
    md.geometry.base = b
    md.geometry.surface = s
    md.geometry.bed = bed

    #####################
    ### update mesh.z ###
    #####################

    if is3d:
        ζ = md.miscellaneous.zeta
        md.mesh.z = b + ζ*H - waterline

    ##################################
    ### inflow boundary conditions ###
    ##################################

    Γ_in = np.isfinite(md.masstransport.spcthickness)
    
    if True in Γ_in:
        if H_in is None:
            raise RuntimeError('Must provide thickness constraint to enforce Dirichlet BC.')
        md.masstransport.spcthickness[Γ_in] = H_in if np.isscalar(H_in) else H_in[Γ_in]

    ############################
    ### transient patameters ###
    ############################

    md.timestepping.time_step = Δt
    md.timestepping.final_time = Δt
    md.transient.isstressbalance = 0
    md.transient.ismasstransport = 1
    md.transient.isthermal = 0
    md.initialization.vx = u[0]
    md.initialization.vy = u[1]
    if stab is not None:
        md.masstransport.stabilization = stab

    ##################
    ### solve step ###
    ##################

    md.geometry.bed -= waterline
    md.geometry.surface -= waterline
    md.geometry.base -= waterline

    md = solve_quiet(md, 'Transient') if quiet else solve(md, 'Transient')
    solution = md.results.TransientSolution[-1]
    H = solution.Thickness.flatten()

    ######################
    ### postprocessing ###
    ######################

    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b = bed.copy()
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        b = bed.copy()

    s = b + H

    md.geometry.thickness = H
    md.geometry.base = b
    md.geometry.surface = s
    md.geometry.bed = bed

    if has_ocean:
        md.mask.ocean_levelset = hb + ϱ*H
    else:
        md.mask.ocean_levelset = np.ones_like(H)

    ##############
    ### output ###
    ##############

    if is3d:
        H, s = proj2(H), proj2(s)
    
    return H, s

# %% [markdown]
# ## ```coupled_solve```
#
# Performs both diagnostic and prognostic solves in a single step. Somewhat faster that splitting. Output is the pair ```(u, H, s)```, where the dimension of ```u``` depends on the approximation.

# %%
def coupled_solve(md, Δt, **kwargs):

    H = kwargs['thickness']
    u = kwargs['velocity']

    bed = kwargs.get('bed', md.geometry.bed.copy())
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)
    H_in = kwargs.get('thickness_inflow', None)
    quiet = kwargs.get('quiet', True)
    stab = kwargs.get('stabilization', 0)
    C = kwargs.get('friction', None)

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    ###########################
    ### resize if necessary ###
    ###########################

    if is3d:
        if (not np.isscalar(H)) and (np.size(H) < md.mesh.numberofvertices):
            H = proj3(H)
        if (H_in is not None) and (not np.isscalar(H_in)) and (np.size(H_in) < md.mesh.numberofvertices):
            H_in = proj3(H_in)

    ####################
    ### set geometry ###
    ####################

    ice_mask = md.mask.ice_levelset <= 0
    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    has_ocean = True in (hb < 0)

    b = bed.copy()
    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        float_mask = np.zeros_like(H, dtype = bool)

    s = b + H

    md.geometry.thickness = H
    md.geometry.base = b
    md.geometry.surface = s

    ######################
    ### basal friction ###
    ######################

    if C is None:
        if md.flowequation.isSSA:
            C = 0
        else:
            raise RuntimeError('Must specify friction coefficient.')

    friction_law = md.miscellaneous.friction_law
    C = friction_law(C)

    md.friction.C = C*np.ones(md.mesh.numberofvertices) if np.isscalar(C) else C
    if has_ocean:
        md.friction.C[float_mask] = 0.0

    #####################
    ### update mesh.z ###
    #####################

    if is3d:
        ζ = md.miscellaneous.zeta
        md.mesh.z = b + ζ*H - waterline

    ###########################
    ### boundary conditions ###
    ###########################

    Γ_x = np.isfinite(md.stressbalance.spcvx)
    Γ_y = np.isfinite(md.stressbalance.spcvy)
    Γ_in = np.isfinite(md.masstransport.spcthickness)

    if True in Γ_x | Γ_y:
        if u is None:
            raise RuntimeError('Must provide initial velocity to enforce Dirichlet BCs.')
        md.stressbalance.spcvx[Γ_x] = u[0] if np.isscalar(u[0]) else u[0][Γ_x]
        md.stressbalance.spcvy[Γ_y] = u[1] if np.isscalar(u[1]) else u[1][Γ_y]

    if True in Γ_in:
        if H_in is None:
            raise RuntimeError('Must provide thickness constraint to enforce Dirichlet BC.')
        md.masstransport.spcthickness[Γ_in] = H_in if np.isscalar(H_in) else H_in[Γ_in]

    ############################
    ### transient patameters ###
    ############################

    md.timestepping.time_step = Δt
    md.timestepping.final_time = Δt
    md.transient.isstressbalance = 1
    md.transient.ismasstransport = 1
    md.transient.isthermal = 0
    md.initialization.vx = u[0]
    md.initialization.vy = u[1]
    if stab is not None:
        md.masstransport.stabilization = stab

    ##################
    ### solve step ###
    ##################

    md.geometry.bed -= waterline
    md.geometry.surface -= waterline
    md.geometry.base -= waterline

    md = solve_quiet(md, 'Transient') if quiet else solve(md, 'Transient')
    solution = md.results.TransientSolution[-1]

    u_x, u_y = solution.Vx.flatten(), solution.Vy.flatten()
    u = (u_x, u_y)
    if is3d:
        u = (u_x, u_y, solution.Vz.flatten())
    H = solution.Thickness.flatten()

    ######################
    ### postprocessing ###
    ######################

    outputs = md.stressbalance.requested_outputs
    requested = [o for o in outputs if o != 'default']
    md.miscellaneous.outputs = SimpleNamespace(**{name: getattr(solution, name) for name in requested})

    ################################
    ### update floating levelset ###
    ################################

    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b = bed.copy()
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        b = bed.copy()

    s = b + H

    md.geometry.thickness = H
    md.geometry.base = b
    md.geometry.surface = s
    md.geometry.bed = bed

    if has_ocean:
        md.mask.ocean_levelset = hb + ϱ*H
    else:
        md.mask.ocean_levelset = np.ones_like(H)

    ##############
    ### output ###
    ##############

    if is3d:
        H, s = proj2(H), proj2(s)

    return u, H, s

# %% [markdown]
# ## ```order_boundary```
#
# Sometimes it is necessary to order boundary nodes by looping from one end of a terminus to the other along the glacier boundary. For example, may want to specify a contiguous section as a named boundary for imposing Dirichlet BCs, or may need to update an ice mask after moving a terminus.

# %%
def order_boundary(md, **kwargs):
    
    mesh2d = md.miscellaneous.mesh2d if hasattr(md.miscellaneous, 'mesh2d') else md.mesh
    x, y = mesh2d.x, mesh2d.y
    bnd = mesh2d.segments[:, :2] - 1
    buf = kwargs.get('buffer', 1.0)

    adj = {}
    for i, j in bnd:
        adj.setdefault(i, []).append(j)
        adj.setdefault(j, []).append(i)

    nodes = np.fromiter(adj.keys(), int)

    # pick a deterministic start: leftmost, then lowest
    start = nodes[np.lexsort((y[nodes], x[nodes]))][0]

    path = [start]
    prev, cur = -1, start
    while True:
        nxts = adj[cur]
        nxt = nxts[0] if nxts[0] != prev else nxts[1]
        if nxt == start:
            break
        path.append(nxt)
        prev, cur = cur, nxt

    bnd_nodes = np.asarray(path)
    md.miscellaneous.bnd_nodes = bnd_nodes
    Ω = Polygon(np.column_stack((x[bnd_nodes], y[bnd_nodes]))).buffer(buf)
    md.miscellaneous.domain = Ω
    return bnd_nodes

# %% [markdown]
# ## ```plot_boundary```
#
# Plot a subset of (already-ordered) boundary from note n to note m. This is necessary for manually chooing the appropriate segments for a given boundary condition.

# %%
def plot_boundary(md, **kwargs):
    
    index_1 = kwargs.get('i', 0)
    index_2 = kwargs.get('j', None)

    figsize = kwargs.get('figsize', (8, 8))
    linewidth = kwargs.get('linewidth', 0.2)
    color = kwargs.get('color', 'k')
    lw = kwargs.get('lw', 2)
    num_ticks = kwargs.get('num_ticks', 50)
    fontsize = kwargs.get('fontsize', 12)

    mesh2d = md.miscellaneous.mesh2d if hasattr(md.miscellaneous, 'mesh2d') else md.mesh
    x, y, tri = mesh2d.x, mesh2d.y, mesh2d.elements - 1

    bnd_nodes = order_boundary(md)
    subset = bnd_nodes[index_1:index_2]

    fig, ax = plt.subplots(figsize = figsize)
    ax.triplot(x, y, tri, linewidth = linewidth)
    ax.plot(x[subset], y[subset], lw = lw, color = color)

    for k in range(0, len(bnd_nodes), num_ticks):
        ax.text(x[bnd_nodes[k]], y[bnd_nodes[k]], str(k), fontsize = fontsize)

    ax.set_aspect('equal')
    plt.show()

# %% [markdown]
# ## ```extend_terminus```
#
# To ensure that the terminus splits the meshed domain, it may at times be necessary to extend the line segment slightly.

# %%
def extend_terminus(md, **kwargs):

    terminus = kwargs['terminus']
    ε = kwargs.get('ε', kwargs.get('epsilon', 10.0))

    Ω = getattr(md.miscellaneous, 'domain', None)
    if Ω is None:
        order_boundary(md)
        Ω = md.miscellaneous.domain

    coords = list(terminus.coords)

    p0 = Point(coords[0])
    if Ω.covers(p0):
        q0 = nearest_points(p0, Ω.boundary)[1]
        p0 = np.asarray(p0.coords[0])
        q0 = np.asarray(q0.coords[0])
        d0 = (q0 - p0)/np.linalg.norm(q0 - p0)
        q0 = q0 + ε*d0
        coords[0:0] = [(q0[0], q0[1])]

    pn = Point(coords[-1])
    if Ω.covers(pn):
        qn = nearest_points(pn, Ω.boundary)[1]
        pn = np.asarray(pn.coords[0])
        qn = np.asarray(qn.coords[0])
        dn = (qn - pn)/np.linalg.norm(qn - pn)
        qn = qn + ε*dn
        coords.append((qn[0], qn[1]))

    return LineString(coords)

# %% [markdown]
# ## ```remove_loops```
#
# Remove self-intersecting regions from the terminus. Sometimes necessary after advance or calving.

# %%
def remove_loops(line, tol = 1e-8):
    xs, ys = line.xy
    pts = [Point(x, y) for x, y in zip(xs, ys)]
    n = len(pts)

    def seg(i):
        return LineString([pts[i], pts[i + 1]])

    # collect intersection points on each segment as (t_along_segment, Point)
    cuts = [[] for _ in range(n - 1)]

    def add_cut(i, p):
        x0, y0 = pts[i].x, pts[i].y
        x1, y1 = pts[i + 1].x, pts[i + 1].y
        dx, dy = x1 - x0, y1 - y0
        denom = dx*dx + dy*dy
        t = 0.0 if denom == 0 else ((p.x - x0)*dx + (p.y - y0)*dy) / denom
        if -tol <= t <= 1.0 + tol:
            cuts[i].append((min(1.0, max(0.0, t)), p))

    for i in range(n - 1):
        si = seg(i)
        for k in range(i + 2, n - 1):
            if i == 0 and k == n - 2:
                continue  # ignore shared endpoints for closed-ish lines
            inter = si.intersection(seg(k))
            if inter.is_empty:
                continue
            if inter.geom_type == 'Point':
                add_cut(i, inter)
                add_cut(k, inter)
            elif inter.geom_type == 'MultiPoint':
                for p in inter.geoms:
                    add_cut(i, p)
                    add_cut(k, p)

    # build noded coordinate sequence
    noded = []
    for i in range(n - 1):
        ts = [(0.0, pts[i]), (1.0, pts[i + 1])] + cuts[i]
        ts.sort(key = lambda z: z[0])
        for _, p in ts[:-1]:
            if not noded or p.distance(noded[-1]) > tol:
                noded.append(p)
    if not noded or pts[-1].distance(noded[-1]) > tol:
        noded.append(pts[-1])

    # remove loops in-order (stack + first-visit index)
    def key(p):
        return (round(p.x/tol)*tol, round(p.y/tol)*tol)

    stack = []
    idx = {}
    for p in noded:
        k = key(p)
        if k in idx:
            j = idx[k]
            for q in stack[j + 1:]:
                idx.pop(key(q), None)
            stack = stack[:j + 1]
        else:
            idx[k] = len(stack)
            stack.append(p)

    return LineString([(p.x, p.y) for p in stack])

# %% [markdown]
# ## ```advance_terminus```
#
# Moves the terminus forward in accordance with the (depth-averaged) frontal velocity field.

# %%
def advance_terminus(md, Δt, **kwargs):

    H = kwargs['thickness']
    u = kwargs['velocity']
    terminus = kwargs['terminus']

    bed = kwargs.get('bed', md.geometry.bed.copy())
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)

    smooth_passes = kwargs.get('smooth_passes', 1)
    step = kwargs.get('step', 5.0)
    smooth_length_change = kwargs.get('smooth_length_change', 0.05)
    debug = kwargs.get('debug', False)

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    def polyline_dist_s(xp, yp, c):
        x0 = c[:-1, 0]
        y0 = c[:-1, 1]
        x1 = c[1:, 0]
        y1 = c[1:, 1]

        vx = x1 - x0
        vy = y1 - y0
        L = np.hypot(vx, vy)
        L[L == 0] = 1.0
        invL2 = 1.0/(L*L)

        s0 = np.r_[0.0, np.cumsum(L)[:-1]]

        dmin2 = np.full(xp.shape, np.inf, float)
        sproj = np.zeros_like(xp, float)

        for j in range(len(L)):
            wx = xp - x0[j]
            wy = yp - y0[j]
            t = (wx*vx[j] + wy*vy[j])*invL2[j]
            t = np.clip(t, 0.0, 1.0)

            dx = wx - t*vx[j]
            dy = wy - t*vy[j]
            d2 = dx*dx + dy*dy

            m = d2 < dmin2
            if np.any(m):
                dmin2[m] = d2[m]
                sproj[m] = s0[j] + t[m]*L[j]

        return np.sqrt(dmin2), sproj

    ###########################
    ### resize if necessary ###
    ###########################

    levelset = md.mask.ice_levelset
    ice_mask = levelset <= 0

    if is3d:
        if np.size(H) == md.mesh.numberofvertices:
            H = proj2(H)
        if np.size(bed) == md.mesh.numberofvertices:
            bed = proj2(bed)
        if np.size(levelset) == md.mesh.numberofvertices:
            levelset = proj2(levelset)
        if np.size(ice_mask) == md.mesh.numberofvertices:
            ice_mask = proj2(ice_mask)

    old_ice = ice_mask.copy()

    ####################
    ### set geometry ###
    ####################

    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    has_ocean = True in (hb < 0)

    b = bed.copy()
    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        float_mask = np.zeros_like(H, dtype = bool)

    s = b + H

    #######################
    ### advect terminus ###
    #######################

    u_x = DepthAverage(md, u[0]) if is3d else u[0]
    u_y = DepthAverage(md, u[1]) if is3d else u[1]

    x, y = md.miscellaneous.mesh2d.x, md.miscellaneous.mesh2d.y
    elts = md.miscellaneous.mesh2d.elements
    xs, ys = map(np.asarray, terminus.xy)

    e = elts[:, [0, 1, 2]] - 1
    dx = x[e[:, [0, 1, 2]]] - x[e[:, [1, 2, 0]]]
    dy = y[e[:, [0, 1, 2]]] - y[e[:, [1, 2, 0]]]
    refinement_size = np.median(np.hypot(dx, dy))

    x_shift = InterpFromMeshToMesh2d(elts, x, y, u_x*Δt, xs, ys).ravel()
    y_shift = InterpFromMeshToMesh2d(elts, x, y, u_y*Δt, xs, ys).ravel()

    c0 = np.column_stack((xs, ys))
    c_adv = np.column_stack((xs + x_shift, ys + y_shift))

    c_uns = c_adv.copy()
    c_uns[0] = c0[0]
    c_uns[-1] = c0[-1]
    terminus_unsmoothed = LineString(c_uns)

    last = getattr(md.miscellaneous, 'last_smoothed_terminus', None)
    if last is None:
        do_smooth = True
    else:
        L0 = last.length
        L1 = terminus_unsmoothed.length
        frac = abs(L1 - L0)/max(L0, 1e-12)
        do_smooth = frac > smooth_length_change

    c = c_adv.copy()
    if do_smooth:
        for _ in range(int(smooth_passes)):
            c[1:-1] = 0.5*c[1:-1] + 0.25*(c[:-2] + c[2:])
    c[0] = c0[0]
    c[-1] = c0[-1]
    terminus_curve = LineString(c)

    if not terminus_curve.is_simple:
        warnings.warn('Warning: Terminus self-intersects in advance_terminus. Removing loop.')
        terminus_curve = remove_loops(terminus_curve)

    terminus_curve = terminus_curve.segmentize(refinement_size)
    L = terminus_curve.length
    ts = np.linspace(0.0, L, len(xs))
    terminus_curve = LineString([terminus_curve.interpolate(t) for t in ts])

    if do_smooth:
        md.miscellaneous.last_smoothed_terminus = terminus_curve

    ######################
    ### domain polygon ###
    ######################

    Ω = getattr(md.miscellaneous, 'domain', None)
    if Ω is None:
        order_boundary(md)
        Ω = md.miscellaneous.domain

    try:
        from shapely.prepared import prep
        Ωp = prep(Ω)
    except Exception:
        Ωp = Ω

    parts = list(split(Ω, terminus_curve).geoms)
    if len(parts) < 2:
        terminus_curve = extend_terminus(md, terminus = terminus_curve)
        parts = list(split(Ω, terminus_curve).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    p0 = Point(x[old_ice][0], y[old_ice][0])
    Ω_ice = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        from shapely.prepared import prep
        Ωicep = prep(Ω_ice)
    except Exception:
        Ωicep = Ω_ice

    ###########################
    ### update ice levelset ###
    ###########################

    c_new = np.asarray(terminus_curve.coords)
    dist, _ = polyline_dist_s(x, y, c_new)

    try:
        import shapely.vectorized as sv
        inside = sv.contains(Ω_ice, x, y) | sv.touches(Ω_ice, x, y)
    except Exception:
        inside = np.array([Ωicep.covers(Point(xi, yi)) for xi, yi in zip(x, y)])

    ice_levelset = np.where(inside, -dist, dist)
    md.mask.ice_levelset = proj3(ice_levelset) if is3d else ice_levelset
    new_ice = inside & (~old_ice)

    ########################
    ### thickness infill ###
    ########################

    H_term = InterpFromMeshToMesh2d(elts, x, y, H, xs, ys).ravel()

    if np.any(new_ice):
        c_old = c0
        ds = np.hypot(np.diff(c_old[:, 0]), np.diff(c_old[:, 1]))
        s_nodes = np.r_[0.0, np.cumsum(ds)]

        _, s_proj = polyline_dist_s(x[new_ice], y[new_ice], c_old)
        H[new_ice] = np.interp(s_proj, s_nodes, H_term)

    ########################################
    ### isostacy and levelset adjustment ###
    ########################################

    if has_ocean:
        float_mask = hb < (-ϱ*H)
        b = bed.copy()
        b[float_mask] = waterline - ϱ*H[float_mask]
    else:
        b = bed.copy()

    s = b + H

    md.mask.ocean_levelset = proj3(hb + ϱ*H) if is3d else hb + ϱ*H
    md.geometry.thickness = proj3(H) if is3d else H
    md.geometry.surface = proj3(s) if is3d else s
    md.geometry.base = proj3(b) if is3d else b

    ##################
    ### debug plot ###
    ##################

    if debug:

        c_old = c0
        c_new = np.asarray(terminus_curve.coords)

        if do_smooth:
            c_uns = np.asarray(terminus_unsmoothed.coords)
            xmin = min(c_old[:, 0].min(), c_uns[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_uns[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_uns[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_uns[:, 1].max(), c_new[:, 1].max())
        else:
            xmin = min(c_old[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_new[:, 1].max())

        pad = 3*refinement_size
        xlo, xhi = xmin - pad, xmax + pad
        ylo, yhi = ymin - pad, ymax + pad

        plt.figure(figsize = (7, 6))
        plt.triplot(x, y, elts - 1, color = 'k', linewidth = 0.2, alpha = 0.25)

        plt.plot(c_old[:, 0], c_old[:, 1],
                 linewidth = 1, color = 'k',
                 label = 'terminus (before)')

        if do_smooth:
            plt.plot(c_uns[:, 0], c_uns[:, 1],
                     linewidth = 1, color = 'k',
                     linestyle = ':', label = 'unsmoothed')

        plt.plot(c_new[:, 0], c_new[:, 1],
                 linewidth = 2, color = 'k',
                 linestyle = '--', label = 'terminus (after)')

        plt.xlim(xlo, xhi)
        plt.ylim(ylo, yhi)
        plt.gca().set_aspect('equal', adjustable = 'box')
        plt.grid(alpha = 0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()

    return terminus_curve, H.flatten(), s.flatten()

# %% [markdown]
# ## ```simple_calve```
#
# Calves a semicircle.

# %%
def simple_calve(md, **kwargs):

    r = kwargs['radius']
    terminus = kwargs['terminus']
    H = kwargs['thickness']

    bed = kwargs.get('bed', md.geometry.bed)
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)

    smooth_passes = kwargs.get('smooth_passes', 1)
    smooth_length_change = kwargs.get('smooth_length_change', 0.05)
    debug = kwargs.get('debug', False)

    ########################################
    ### initialize some important pieces ###
    ########################################

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    x, y = md.miscellaneous.mesh2d.x, md.miscellaneous.mesh2d.y
    elts = md.miscellaneous.mesh2d.elements
    xs, ys = map(np.asarray, terminus.xy)

    e = elts[:, [0, 1, 2]] - 1
    dx = x[e[:, [0, 1, 2]]] - x[e[:, [1, 2, 0]]]
    dy = y[e[:, [0, 1, 2]]] - y[e[:, [1, 2, 0]]]
    refinement_size = np.median(np.hypot(dx, dy))

    ###########################
    ### resize if necessary ###
    ###########################

    levelset = md.mask.ice_levelset
    ice_mask = levelset <= 0

    if is3d:
        if np.size(H) == md.mesh.numberofvertices:
            H = proj2(H)
        if np.size(bed) == md.mesh.numberofvertices:
            bed = proj2(bed)
        if np.size(levelset) == md.mesh.numberofvertices:
            levelset = proj2(levelset)
        if np.size(ice_mask) == md.mesh.numberofvertices:
            ice_mask = proj2(ice_mask)

    old_ice = ice_mask.copy()

    ####################
    ### set geometry ###
    ####################

    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    float_mask = hb < (-ϱ*H)
    b = bed.copy()
    b[float_mask] = waterline - ϱ*H[float_mask]
    s = b + H

    ######################
    ### domain polygon ###
    ######################

    Ω = getattr(md.miscellaneous, 'domain', None)
    if Ω is None:
        order_boundary(md)
        Ω = md.miscellaneous.domain

    try:
        from shapely.prepared import prep
        Ωp = prep(Ω)
    except Exception:
        Ωp = Ω

    parts = list(split(Ω, terminus).geoms)
    if len(parts) < 2:
        terminus = extend_terminus(md, terminus = terminus)
        parts = list(split(Ω, terminus).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    p0 = Point(x[old_ice][0], y[old_ice][0])
    Ω_ice_old = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        Ωicep_old = prep(Ω_ice_old)
    except Exception:
        Ωicep_old = Ω_ice_old

    ##############################
    ### carve semicircle in curve
    ##############################

    c0 = np.column_stack((xs, ys))
    c = c0.copy()

    mid = c[len(c)//2]
    d = c - mid

    t = c[-1] - c[0]
    tn = np.linalg.norm(t)
    tn = tn if tn != 0 else 1.0
    t = t/tn
    n = np.array([-t[1], t[0]])

    eps = 1e-6*r + 1.0
    n_in = n if Ωicep_old.covers(Point(*(mid + eps*n))) else -n

    dt = d @ t
    mask = np.abs(dt) <= r
    indent = np.sqrt(np.maximum(0.0, r*r - dt[mask]**2))

    c[mask] = c[mask] + indent[:, None]*n_in[None, :]
    c[0] = c0[0]
    c[-1] = c0[-1]

    terminus_unsmoothed = LineString(c)

    last = getattr(md.miscellaneous, 'last_smoothed_terminus', None)
    if last is None:
        do_smooth = True
    else:
        L0 = last.length
        L1 = terminus_unsmoothed.length
        frac = abs(L1 - L0)/max(L0, 1e-12)
        do_smooth = frac > smooth_length_change

    terminus = terminus_unsmoothed

    ############################
    ### smoothing + resample ###
    ############################

    if not terminus.is_simple:
        warnings.warn('Warning: Terminus self-intersects in simple_calve. Removing loop.')
        terminus = remove_loops(terminus)

    c = np.column_stack(terminus.xy)
    if do_smooth:
        for _ in range(int(smooth_passes)):
            c[1:-1] = 0.5*c[1:-1] + 0.25*(c[:-2] + c[2:])
    terminus = LineString(c)

    terminus = terminus.segmentize(refinement_size)
    L = terminus.length
    ts = np.linspace(0.0, L, len(xs))
    terminus = LineString([terminus.interpolate(t) for t in ts])

    if do_smooth:
        md.miscellaneous.last_smoothed_terminus = terminus
        if hasattr(md.miscellaneous, 'time_since_last_smooth'):
            md.miscellaneous.time_since_last_smooth = 0.0

    #######################
    ### updated polygon ###
    #######################

    parts = list(split(Ω, terminus).geoms)
    if len(parts) < 2:
        terminus = extend_terminus(md, terminus = terminus)
        parts = list(split(Ω, terminus).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    Ω_ice = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        Ωicep = prep(Ω_ice)
    except Exception:
        Ωicep = Ω_ice

    ##################
    ### debug plot ###
    ##################

    if debug:

        c_old = c0
        c_new = np.asarray(terminus.coords)

        if do_smooth:
            c_uns = np.asarray(terminus_unsmoothed.coords)
            xmin = min(c_old[:, 0].min(), c_uns[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_uns[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_uns[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_uns[:, 1].max(), c_new[:, 1].max())
        else:
            xmin = min(c_old[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_new[:, 1].max())

        pad = 3*refinement_size
        xlo, xhi = xmin - pad, xmax + pad
        ylo, yhi = ymin - pad, ymax + pad

        plt.figure(figsize = (7, 6))
        plt.triplot(x, y, elts - 1, color = 'k', linewidth = 0.2, alpha = 0.25)

        plt.plot(c_old[:, 0], c_old[:, 1], linewidth = 1, color = 'k', label = 'terminus (before)')

        if do_smooth:
            plt.plot(c_uns[:, 0], c_uns[:, 1],
                     linewidth = 1, color = 'k',
                     linestyle = 'dashdot', label = 'unsmoothed')

        plt.plot(c_new[:, 0], c_new[:, 1], linewidth = 2, color = 'k', linestyle = '--', label = 'terminus (after)')

        plt.xlim(xlo, xhi)
        plt.ylim(ylo, yhi)
        plt.gca().set_aspect('equal', adjustable = 'box')
        plt.grid(alpha = 0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()

    ###########################
    ### update ice levelset ###
    ###########################

    dist = np.array([terminus.distance(Point(xi, yi)) for xi, yi in zip(x, y)])
    inside = np.array([Ωicep.covers(Point(xi, yi)) for xi, yi in zip(x, y)])
    ice_levelset = np.where(inside, -dist, dist)
    md.mask.ice_levelset = proj3(ice_levelset) if is3d else ice_levelset

    ###############################
    ### calved-off: thin + flat ###
    ###############################

    calved = old_ice & (~inside)
    H[calved] = 1e-3
    s[calved] = waterline + (1 - ϱ)*H[calved]
    b[calved] = s[calved] - H[calved]

    md.mask.ocean_levelset = proj3(hb + ϱ*H) if is3d else hb + ϱ*H
    md.geometry.thickness = proj3(H) if is3d else H
    md.geometry.surface = proj3(s) if is3d else s
    md.geometry.base = proj3(b) if is3d else b

    return terminus, H.flatten(), s.flatten()

# %% [markdown]
# ## ```rate_law```
#
# A rate-based calving law. Retreats the terminus at a rate of ```rate``` metres per year. The value of ```rate``` is evaluated at each terminus node, and that point retreats upstream by the prescribed amount.

# %%
def rate_law(md, Δt, **kwargs):

    terminus = kwargs['terminus']
    H = kwargs['thickness']

    rate = kwargs['rate']              # scalar, or nodal field (2D)
    bed = kwargs.get('bed', md.geometry.bed)
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)

    smooth_passes = kwargs.get('smooth_passes', 1)
    step = kwargs.get('step', 5.0)
    smooth_length_change = kwargs.get('smooth_length_change', 0.05)
    debug = kwargs.get('debug', False)

    ########################################
    ### initialize some important pieces ###
    ########################################

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    x, y = md.miscellaneous.mesh2d.x, md.miscellaneous.mesh2d.y
    elts = md.miscellaneous.mesh2d.elements
    xs, ys = map(np.asarray, terminus.xy)

    if not hasattr(md.miscellaneous, 'termini'):
        md.miscellaneous.termini = [terminus]

    if not hasattr(md.miscellaneous, 'calved_area'):
        md.miscellaneous.calved_area = []

    e = elts[:, [0, 1, 2]] - 1
    dx = x[e[:, [0, 1, 2]]] - x[e[:, [1, 2, 0]]]
    dy = y[e[:, [0, 1, 2]]] - y[e[:, [1, 2, 0]]]
    refinement_size = np.median(np.hypot(dx, dy))

    ###########################
    ### resize if necessary ###
    ###########################

    levelset = md.mask.ice_levelset
    ice_mask = levelset <= 0

    if is3d:
        if np.size(H) == md.mesh.numberofvertices:
            H = proj2(H)
        if np.size(bed) == md.mesh.numberofvertices:
            bed = proj2(bed)
        if np.size(levelset) == md.mesh.numberofvertices:
            levelset = proj2(levelset)
        if np.size(ice_mask) == md.mesh.numberofvertices:
            ice_mask = proj2(ice_mask)
        if (not np.isscalar(rate)) and np.size(rate) == md.mesh.numberofvertices:
            rate = proj2(rate)

    old_ice = ice_mask.copy()

    ####################
    ### set geometry ###
    ####################

    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    float_mask = hb < (-ϱ*H)
    b = bed.copy()
    b[float_mask] = waterline - ϱ*H[float_mask]
    s = b + H

    ######################
    ### domain polygon ###
    ######################

    Ω = getattr(md.miscellaneous, 'domain', None)
    if Ω is None:
        order_boundary(md)
        Ω = md.miscellaneous.domain

    try:
        from shapely.prepared import prep
        Ωp = prep(Ω)
    except Exception:
        Ωp = Ω

    parts = list(split(Ω, terminus).geoms)
    if len(parts) < 2:
        terminus = extend_terminus(md, terminus = terminus)
        parts = list(split(Ω, terminus).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    p0 = Point(x[old_ice][0], y[old_ice][0])
    Ω_ice_old = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        Ωicep_old = prep(Ω_ice_old)
    except Exception:
        Ωicep_old = Ω_ice_old

    ##############################
    ### inward normals (pinned) ###
    ##############################

    c0 = np.column_stack((xs, ys))

    t = np.zeros_like(c0)
    t[1:-1] = c0[2:] - c0[:-2]
    t[0] = c0[1] - c0[0]
    t[-1] = c0[-1] - c0[-2]
    tn = np.linalg.norm(t, axis = 1)
    tn[tn == 0] = 1.0
    t = t/tn[:, None]

    n = np.column_stack((-t[:, 1], t[:, 0]))

    ε = step
    k = len(c0)//2
    test = c0[k] + ε*n[k]
    n_inward = n if Ωicep_old.covers(Point(test[0], test[1])) else -n

    ########################################
    ### retreat distance along the curve ###
    ########################################

    if np.isscalar(rate):
        retreat = float(rate)*Δt*np.ones(len(xs))
        rate_on_term = None
        ε_samp = None
    else:
        ε_samp = 1*refinement_size
        xs_step = xs + ε_samp*n_inward[:, 0]
        ys_step = ys + ε_samp*n_inward[:, 1]
        rate_on_term = InterpFromMeshToMesh2d(elts, x, y, rate, xs_step, ys_step).ravel()
        retreat = rate_on_term*Δt

    retreat = np.maximum(0.0, retreat)

    if np.all(retreat == 0):
        md.miscellaneous.termini.append(terminus)
        md.miscellaneous.calved_area.append(0)
        return terminus, H, s

    ##############################################
    ### cap retreat where bed rises above WL   ###
    ##############################################

    retreat_cap = retreat.copy()

    px = np.empty(1, float)
    py = np.empty(1, float)

    for i in range(1, len(c0) - 1):
        if retreat_cap[i] <= 0:
            continue

        p = c0[i].copy()
        ni = n_inward[i]
        dist = 0.0

        while dist < retreat_cap[i]:

            p = p + step*ni
            dist += step

            if not Ωp.covers(Point(p[0], p[1])):
                retreat_cap[i] = max(0.0, dist - step)
                break

            px[0] = p[0]
            py[0] = p[1]

            bed_i = InterpFromMeshToMesh2d(elts, x, y, bed, px, py).ravel()[0]
            if bed_i >= waterline:
                retreat_cap[i] = max(0.0, dist - step)
                break

    retreat = retreat_cap

    c_new = c0.copy()
    c_new[1:-1] = c_new[1:-1] + retreat[1:-1, None]*n_inward[1:-1]

    ###########################
    ### trim outside domain ###
    ###########################

    in_dom = np.array([Ωp.covers(Point(p[0], p[1])) for p in c_new])
    ids = np.where(in_dom)[0]

    if ids.size >= 2:
        α = int(ids[0])
        β = int(ids[-1])

        pts = []
        pts.append(c_new[α - 1] if α > 0 else c_new[α])
        pts.extend(c_new[α:β + 1])
        pts.append(c_new[β + 1] if β < len(c_new) - 1 else c_new[β])

        c_new = np.asarray(pts, float)

    terminus_unsmoothed = LineString(c_new)

    last = getattr(md.miscellaneous, 'last_smoothed_terminus', None)
    if last is None:
        do_smooth = True
    else:
        L0 = last.length
        L1 = terminus_unsmoothed.length
        frac = abs(L1 - L0)/max(L0, 1e-12)
        do_smooth = frac > smooth_length_change

    terminus = terminus_unsmoothed

    ############################
    ### smoothing + resample ###
    ############################

    if not terminus.is_simple:
        warnings.warn('Warning: Terminus self-intersects in rate_law. Removing loop.')
        terminus = remove_loops(terminus)

    c = np.column_stack(terminus.xy)
    if do_smooth:
        for _ in range(int(smooth_passes)):
            c[1:-1] = 0.5*c[1:-1] + 0.25*(c[:-2] + c[2:])
    terminus = LineString(c)

    terminus = terminus.segmentize(refinement_size)
    L = terminus.length
    ts = np.linspace(0.0, L, len(xs))
    terminus = LineString([terminus.interpolate(t) for t in ts])

    if do_smooth:
        md.miscellaneous.last_smoothed_terminus = terminus

    #######################
    ### updated polygon ###
    #######################

    parts = list(split(Ω, terminus).geoms)
    if len(parts) < 2:
        terminus = extend_terminus(md, terminus = terminus)
        parts = list(split(Ω, terminus).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    Ω_ice = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        Ωicep = prep(Ω_ice)
    except Exception:
        Ωicep = Ω_ice

    ##################
    ### debug plot ###
    ##################

    if debug:

        c_old = c0
        c_new = np.asarray(terminus.coords)

        if do_smooth:
            c_uns = np.asarray(terminus_unsmoothed.coords)
            xmin = min(c_old[:, 0].min(), c_uns[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_uns[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_uns[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_uns[:, 1].max(), c_new[:, 1].max())
        else:
            xmin = min(c_old[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_new[:, 1].max())

        pad = 3*refinement_size
        xlo, xhi = xmin - pad, xmax + pad
        ylo, yhi = ymin - pad, ymax + pad

        if rate_on_term is None:
            xs_samp = None
            ys_samp = None
        else:
            xs_samp = c_old[:, 0] + ε_samp*n_inward[:, 0]
            ys_samp = c_old[:, 1] + ε_samp*n_inward[:, 1]

        plt.figure(figsize = (7, 6))

        if np.isscalar(rate):
            plt.triplot(x, y, elts - 1, color = 'k', linewidth = 0.2, alpha = 0.25)
        else:
            in_view = (x >= xlo) & (x <= xhi) & (y >= ylo) & (y <= yhi)
            vmax = np.nanpercentile(rate[in_view], 98)
            vmax = max(vmax, 1e-12)
            pc = plt.tripcolor(x, y, elts - 1, rate,
                               vmin = 0.0, vmax = vmax,
                               cmap = 'seismic')
            plt.colorbar(pc, label = 'rate')

        plt.plot(c_old[:, 0], c_old[:, 1], linewidth = 1, color = 'k', label = 'terminus (before)')

        if do_smooth:
            plt.plot(c_uns[:, 0], c_uns[:, 1],
                     linewidth = 1, color = 'k',
                     linestyle = 'dashdot', label = 'unsmoothed')

        plt.plot(c_new[:, 0], c_new[:, 1], linewidth = 2, color = 'k', linestyle = '--', label = 'terminus (after)')

        if xs_samp is not None:
            plt.plot(xs_samp, ys_samp, linewidth = 1, linestyle = ':', color = 'tab:green', label = 'sampling curve')

        plt.xlim(xlo, xhi)
        plt.ylim(ylo, yhi)
        plt.gca().set_aspect('equal', adjustable = 'box')
        plt.grid(alpha = 0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()

    ###########################
    ### calved area tracker ###
    ###########################

    calved_area = float(Ω_ice_old.difference(Ω_ice).area)
    if calved_area <= 0:
        calved_area = 0.0
    md.miscellaneous.calved_area.append(calved_area)

    ###########################
    ### update ice levelset ###
    ###########################

    dist = np.array([terminus.distance(Point(xi, yi)) for xi, yi in zip(x, y)])
    inside = np.array([Ωicep.covers(Point(xi, yi)) for xi, yi in zip(x, y)])
    ice_levelset = np.where(inside, -dist, dist)
    md.mask.ice_levelset = proj3(ice_levelset) if is3d else ice_levelset

    ###############################
    ### calved-off: thin + flat ###
    ###############################

    calved = old_ice & (~inside)
    H[calved] = 1e-3
    s[calved] = (1 - ϱ)*H[calved]
    b[calved] = s[calved] - H[calved]

    ocean_levelset = hb + ϱ*H
    md.mask.ocean_levelset = proj3(ocean_levelset) if is3d else ocean_levelset
    md.geometry.thickness = proj3(H) if is3d else H
    md.geometry.surface = proj3(s) if is3d else s
    md.geometry.base = proj3(b) if is3d else b

    md.miscellaneous.termini.append(terminus)
    return terminus, H.flatten(), s.flatten()

# %% [markdown]
# ## ```position_law```
#
# A position-based calving law. Has two modes: ```search_mode = local``` does this:
#
#
# ```
# for each point on terminus:
#         if that point's forcing exceeds the threshold value:
#             retreat that point upstream until the threshold is no longer met
#             also do some smoothing if necessary
# ```
# This is meant to capture local calving mechanisms, where forcings acting on the terminus itself cause calving. Alternatively, we can set ```search_mode = nonlocal```, in which case:
#
# ```
# for each point on terminus:
#     search upstream until we encounter a region with forcing > threshold
#     if we do not encounter such a region within a reasonable distance:
#         do not calve this node
#     otherwise, after encountering the exceedence condition:
#         continue searching upstream until either (1) we lose the exceedence condition, (2) bed > waterline, or (3) we run out of ice
#         calve back whichever of those 3 stopping points we encountered
#         also smoothing
# ```
#
# This captures nonlocal calving mechanisms, where frontal retreat may have little to do with forces acting on the terminus.

# %%
def position_law(md, **kwargs):

    forcing = kwargs['forcing']
    threshold = kwargs['threshold']
    terminus = kwargs['terminus']

    H = kwargs.get('thickness', md.geometry.thickness)
    bed = kwargs.get('bed', md.geometry.bed)
    waterline = kwargs.get('waterline', md.miscellaneous.waterline)

    smooth_passes = kwargs.get('smooth_passes', 1)
    step = kwargs.get('step', 5.0)
    smooth_length_change = kwargs.get('smooth_length_change', 0.05)
    debug = kwargs.get('debug', False)

    search_mode = kwargs.get('search_mode', None)
    if search_mode not in ['local', 'nonlocal']:
        raise RuntimeError("position_law: must specify search_mode in {'local','nonlocal'}.")

    max_search_distance = kwargs.get('max_search_distance', None)

    #######################################
    ### initialize some stuff for later ###
    #######################################

    ρ_i = md.materials.rho_ice
    ρ_w = md.materials.rho_water
    ϱ = ρ_i/ρ_w

    proj2 = lambda x: project2d(md, x, 1)
    proj3 = lambda x: project3d(md, 'vector', x, 'type', 'node')

    is3d = md.miscellaneous.is3d

    x, y = md.miscellaneous.mesh2d.x, md.miscellaneous.mesh2d.y
    elts = md.miscellaneous.mesh2d.elements
    xs, ys = map(np.asarray, terminus.xy)

    if not hasattr(md.miscellaneous, 'termini'):
        md.miscellaneous.termini = [terminus]

    if not hasattr(md.miscellaneous, 'calved_area'):
        md.miscellaneous.calved_area = []

    e = elts[:, [0, 1, 2]] - 1
    dx = x[e[:, [0, 1, 2]]] - x[e[:, [1, 2, 0]]]
    dy = y[e[:, [0, 1, 2]]] - y[e[:, [1, 2, 0]]]
    refinement_size = np.median(np.hypot(dx, dy))

    ###########################
    ### resize if necessary ###
    ###########################

    levelset = md.mask.ice_levelset
    ice_mask = levelset <= 0

    if is3d:
        if np.size(H) == md.mesh.numberofvertices:
            H = proj2(H)
        if np.size(bed) == md.mesh.numberofvertices:
            bed = proj2(bed)
        if np.size(forcing) == md.mesh.numberofvertices:
            forcing = proj2(forcing)
        if np.size(levelset) == md.mesh.numberofvertices:
            levelset = proj2(levelset)
        if np.size(ice_mask) == md.mesh.numberofvertices:
            ice_mask = proj2(ice_mask)

    old_ice = ice_mask.copy()

    ####################
    ### set geometry ###
    ####################

    H[(~ice_mask) | (H <= 0)] = 1e-3

    hb = bed - waterline
    float_mask = hb < (-ϱ*H)
    b = bed.copy()
    b[float_mask] = waterline - ϱ*H[float_mask]
    s = b + H

    ######################
    ### domain polygon ###
    ######################

    Ω = getattr(md.miscellaneous, 'domain', None)
    if Ω is None:
        order_boundary(md)
        Ω = md.miscellaneous.domain

    try:
        from shapely.prepared import prep
        Ωp = prep(Ω)
    except Exception:
        Ωp = Ω

    parts = list(split(Ω, terminus).geoms)
    if len(parts) < 2:
        terminus = extend_terminus(md, terminus = terminus)
        parts = list(split(Ω, terminus).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    p0 = Point(x[old_ice][0], y[old_ice][0])
    Ω_ice_old = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        Ωicep_old = prep(Ω_ice_old)
    except Exception:
        Ωicep_old = Ω_ice_old

    ##############################
    ### inward normals (pinned) ###
    ##############################

    c0 = np.column_stack((xs, ys))

    t = np.zeros_like(c0)
    t[1:-1] = c0[2:] - c0[:-2]
    t[0] = c0[1] - c0[0]
    t[-1] = c0[-1] - c0[-2]
    tn = np.linalg.norm(t, axis = 1)
    tn[tn == 0] = 1.0
    t = t/tn[:, None]

    n = np.column_stack((-t[:, 1], t[:, 0]))

    ε = step
    k = len(c0)//2
    test = c0[k] + ε*n[k]
    n_inward = n if Ωicep_old.covers(Point(test[0], test[1])) else -n

    ############################################
    ### retreat distances by marching inward ###
    ############################################

    ε_samp = 1*refinement_size
    xs_in = xs + ε_samp*n_inward[:, 0]
    ys_in = ys + ε_samp*n_inward[:, 1]
    f_on_term = InterpFromMeshToMesh2d(elts, x, y, forcing, xs_in, ys_in)

    active = (f_on_term > threshold) if search_mode == 'local' else np.ones_like(f_on_term, dtype = bool)
    active[0] = False
    active[-1] = False

    retreat = np.zeros(len(xs), float)

    px = np.empty(1, float)
    py = np.empty(1, float)

    for i in range(1, len(xs) - 1):
        if not active[i]:
            continue

        p = c0[i].copy()
        ni = n_inward[i]
        dist = 0.0

        in_exceed = (f_on_term[i] > threshold) if search_mode == 'nonlocal' else None

        while True:
            p = p + step*ni
            dist += step

            if (max_search_distance is not None) and (dist >= max_search_distance):
                if (search_mode == 'nonlocal') and in_exceed:
                    retreat[i] = max(0.0, dist - step)
                break

            if not Ωp.covers(Point(p[0], p[1])):
                if (search_mode == 'nonlocal') and in_exceed:
                    retreat[i] = max(0.0, dist - step)
                break

            px[0] = p[0]
            py[0] = p[1]

            bed_i = InterpFromMeshToMesh2d(elts, x, y, bed, px, py).ravel()[0]
            if bed_i >= waterline:
                if (search_mode == 'nonlocal') and in_exceed:
                    retreat[i] = max(0.0, dist - step)
                break

            fi = InterpFromMeshToMesh2d(elts, x, y, forcing, px, py).ravel()[0]

            if search_mode == 'local':
                if fi <= threshold:
                    retreat[i] = dist
                    break
            else:
                if (not in_exceed) and (fi > threshold):
                    in_exceed = True
                elif in_exceed and (fi <= threshold):
                    retreat[i] = dist
                    break

    # bed/WL cap
    retreat_cap = retreat.copy()
    for i in range(1, len(c0) - 1):
        if retreat_cap[i] <= 0:
            continue

        p = c0[i].copy()
        ni = n_inward[i]
        dist = 0.0

        while dist < retreat_cap[i]:
            p = p + step*ni
            dist += step

            if not Ωp.covers(Point(p[0], p[1])):
                retreat_cap[i] = max(0.0, dist - step)
                break

            px[0] = p[0]
            py[0] = p[1]

            bed_i = InterpFromMeshToMesh2d(elts, x, y, bed, px, py).ravel()[0]
            if bed_i >= waterline:
                retreat_cap[i] = max(0.0, dist - step)
                break

    retreat = retreat_cap

    if np.all(retreat == 0):
        md.miscellaneous.termini.append(terminus)
        md.miscellaneous.calved_area.append(0)
        return terminus, H, s

    ###########################################
    ### concavity cap (loop reject) + apply ###
    ###########################################

    retreat_try = retreat.copy()

    concavity_k = 5
    concavity_factor = 2.0
    concavity_iters = 20

    for _ in range(concavity_iters):
        c_try = c0.copy()
        c_try[1:-1] = c_try[1:-1] + retreat_try[1:-1, None]*n_inward[1:-1]

        bad = np.zeros(len(c_try), bool)

        for i in range(0, len(c_try) - concavity_k):
            d = np.linalg.norm(c_try[i + concavity_k] - c_try[i])
            if d == 0:
                continue
            for j in range(1, concavity_k):
                if np.linalg.norm(c_try[i + j] - c_try[i]) > concavity_factor*d:
                    bad[i + j] = True

        bad[0] = False
        bad[-1] = False

        if not np.any(bad):
            break

        ids = np.where(bad & (retreat_try > 0))[0]
        if ids.size == 0:
            break

        retreat_try[ids[np.argmax(retreat_try[ids])]] = 0.0

    c_new = c0.copy()
    c_new[1:-1] = c_new[1:-1] + retreat_try[1:-1, None]*n_inward[1:-1]

    ###########################
    ### trim outside domain ###
    ###########################

    in_dom = np.array([Ωp.covers(Point(p[0], p[1])) for p in c_new])
    ids = np.where(in_dom)[0]

    if ids.size >= 2:
        α = int(ids[0])
        β = int(ids[-1])

        pts = []
        pts.append(c_new[α - 1] if α > 0 else c_new[α])
        pts.extend(c_new[α:β + 1])
        pts.append(c_new[β + 1] if β < len(c_new) - 1 else c_new[β])

        c_new = np.asarray(pts, float)

    terminus_unsmoothed = LineString(c_new)

    last = getattr(md.miscellaneous, 'last_smoothed_terminus', None)
    if last is None:
        do_smooth = True
    else:
        L0 = last.length
        L1 = terminus_unsmoothed.length
        frac = abs(L1 - L0)/max(L0, 1e-12)
        do_smooth = frac > smooth_length_change

    terminus = terminus_unsmoothed

    ############################
    ### smoothing + resample ###
    ############################

    if not terminus.is_simple:
        warnings.warn('Warning: Terminus self-intersects in position_law. Removing loop.')
        terminus = remove_loops(terminus)

    c = np.column_stack(terminus.xy)
    if do_smooth:
        for _ in range(int(smooth_passes)):
            c[1:-1] = 0.5*c[1:-1] + 0.25*(c[:-2] + c[2:])
    terminus = LineString(c)

    terminus = terminus.segmentize(refinement_size)
    L = terminus.length
    ts = np.linspace(0.0, L, len(xs))
    terminus = LineString([terminus.interpolate(t) for t in ts])

    if do_smooth:
        md.miscellaneous.last_smoothed_terminus = terminus
        if hasattr(md.miscellaneous, 'time_since_last_smooth'):
            md.miscellaneous.time_since_last_smooth = 0.0

    #######################
    ### updated polygon ###
    #######################

    parts = list(split(Ω, terminus).geoms)
    if len(parts) < 2:
        terminus = extend_terminus(md, terminus = terminus)
        parts = list(split(Ω, terminus).geoms)
        if len(parts) < 2:
            raise RuntimeError('Split failed.')

    Ω_ice = parts[0] if parts[0].covers(p0) else parts[1]

    try:
        Ωicep = prep(Ω_ice)
    except Exception:
        Ωicep = Ω_ice

    ##################
    ### debug plot ###
    ##################

    if debug:
    
        c_old = c0
        c_new = np.asarray(terminus.coords)
    
        if do_smooth:
            c_uns = np.asarray(terminus_unsmoothed.coords)
            xmin = min(c_old[:, 0].min(), c_uns[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_uns[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_uns[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_uns[:, 1].max(), c_new[:, 1].max())
        else:
            xmin = min(c_old[:, 0].min(), c_new[:, 0].min())
            xmax = max(c_old[:, 0].max(), c_new[:, 0].max())
            ymin = min(c_old[:, 1].min(), c_new[:, 1].min())
            ymax = max(c_old[:, 1].max(), c_new[:, 1].max())
    
        pad = 3*refinement_size
        xlo, xhi = xmin - pad, xmax + pad
        ylo, yhi = ymin - pad, ymax + pad
    
        in_view = (x >= xlo) & (x <= xhi) & (y >= ylo) & (y <= yhi)
    
        if threshold > 0:
            vmin = 0.0
            vmax = 2.0*threshold
        else:
            absmax = np.nanpercentile(np.abs(forcing[in_view]), 98)
            if (not np.isfinite(absmax)) or (absmax <= 0):
                absmax = np.nanmax(np.abs(forcing[in_view]))
            if (not np.isfinite(absmax)) or (absmax <= 0):
                absmax = 1.0
            vmin = -absmax
            vmax = absmax
    
        plt.figure(figsize = (7, 6))
        pc = plt.tripcolor(x, y, elts - 1, forcing, cmap = 'seismic', vmin = vmin, vmax = vmax)
    
        plt.plot(c_old[:, 0], c_old[:, 1], linewidth = 1, color = 'k', label = 'terminus (before)')
    
        if do_smooth:
            plt.plot(c_uns[:, 0], c_uns[:, 1],
                     linewidth = 1, color = 'k',
                     linestyle = 'dashdot', label = 'unsmoothed')
    
        plt.plot(c_new[:, 0], c_new[:, 1], linewidth = 2, color = 'k', linestyle = '--', label = 'terminus (after)')
    
        plt.xlim(xlo, xhi)
        plt.ylim(ylo, yhi)
        plt.gca().set_aspect('equal', adjustable = 'box')
        plt.colorbar(pc, label = 'forcing')
        plt.grid(alpha = 0.3)
        plt.legend()
        plt.tight_layout()
        plt.show()

    ###########################
    ### calved area tracker ###
    ###########################

    calved_area = float(Ω_ice_old.difference(Ω_ice).area)
    if calved_area <= 0:
        calved_area = 0.0
    md.miscellaneous.calved_area.append(calved_area)

    ###########################
    ### update ice levelset ###
    ###########################

    dist = np.array([terminus.distance(Point(xi, yi)) for xi, yi in zip(x, y)])
    inside = np.array([Ωicep.covers(Point(xi, yi)) for xi, yi in zip(x, y)])
    ice_levelset = np.where(inside, -dist, dist)
    md.mask.ice_levelset = proj3(ice_levelset) if is3d else ice_levelset

    ###############################
    ### calved-off: thin + flat ###
    ###############################

    calved = old_ice & (~inside)
    H[calved] = 1e-3
    s[calved] = (1 - ϱ)*H[calved]
    b[calved] = s[calved] - H[calved]

    ocean_levelset = hb + ϱ*H
    md.mask.ocean_levelset = proj3(ocean_levelset) if is3d else ocean_levelset
    md.geometry.thickness = proj3(H) if is3d else H
    md.geometry.surface = proj3(s) if is3d else s
    md.geometry.base = proj3(b) if is3d else b

    md.miscellaneous.termini.append(terminus)
    return terminus, H.flatten(), s.flatten()

# %% [markdown]
# ## ```interpolate_raster```
#
# Raster to mesh gridpoints.

# %%
def interpolate_raster(md, raster, **kwargs):

    mesh = md.miscellaneous.mesh2d if hasattr(md.miscellaneous, 'mesh2d') else md.mesh
    x, y = mesh.x, mesh.y

    fill = kwargs.get('fill', True)
    epsg = kwargs.get('epsg', 32645)
    mesh_crs = f'EPSG:{epsg}'   

    with rasterio.open(raster) as src:

        z = src.read(1).astype(float)
        t = src.transform
        ny, nx = z.shape
        src_crs = src.crs

        if fill:
            z = fillnodata(z, mask = np.isfinite(z))

        cols = np.arange(nx) + 0.5
        rows = np.arange(ny) + 0.5

        xs = t.c + cols*t.a
        ys = t.f + rows*t.e

        if ys[1] < ys[0]:
            ys = ys[::-1]
            z = z[::-1, :]

        # Transform mesh → raster CRS if needed
        if src_crs is not None and str(src_crs) != mesh_crs:
            x, y = transform(mesh_crs, src_crs, x.tolist(), y.tolist())
            x = np.asarray(x)
            y = np.asarray(y)

    vals = InterpFromGridToMesh(xs, ys, z, x, y, np.nan)
    return vals

# %% [markdown]
# ## ```effective_strain_rate```

# %%
def effective_strain_rate(md, **kwargs):

    depth_averaged = kwargs.get('depth_averaged', False) if md.flowequation.isHO else False #SSA is already dpth-averaged by default
    out = md.miscellaneous.outputs
    ε_xx, ε_xy, ε_yy = out.StrainRatexx, out.StrainRatexy, out.StrainRateyy
    
    inner_ε =  ε_xx**2 + 2*ε_xy**2 + ε_yy**2
    trace_ε = ε_xx + ε_yy
    
    if md.flowequation.isHO:
        ε_xz, ε_yz, ε_zz = out.StrainRatexz, out.StrainRateyz, out.StrainRatezz
        inner_ε += ε_zz**2 + 2*ε_xz**2 + 2*ε_yz**2
        trace_ε += ε_zz
    
    ε_e = np.sqrt(1/2*(inner_ε + trace_ε**2)) #generally true since the trace term should be zero in 3D
    ε_e = ε_e if not depth_averaged else DepthAverage(md, ε_e)

    return ε_e.flatten()

# %% [markdown]
# ## Convert to .py script

# %%
# !jupyter nbconvert --to script issm_helper.ipynb
